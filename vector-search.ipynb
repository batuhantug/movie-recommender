# %%
import re
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma
from langchain.embeddings import HuggingFaceEmbeddings

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import pandas as pd

movies = pd.read_csv("movies_cleaned.csv")

# %%
# add sign for splitting
movies["tagged_plots"] = movies["tagged_plots"] + "***"

# %%
movies["tagged_plots"].to_csv("tagged_plots.txt",
                                   sep = "\n",
                                   index = False,
                                   header = False)

# %%
raw_documents = TextLoader("tagged_plots.txt", encoding="utf-8").load()
text_splitter = CharacterTextSplitter(chunk_size=0, chunk_overlap=0, separator="***")
documents = text_splitter.split_documents(raw_documents)
# Out:
# Created a chunk of size 505, which is longer than the specified 0
# Created a chunk of size 446, which is longer than the specified 0
# Created a chunk of size 446, which is longer than the specified 0
# Created a chunk of size 911, which is longer than the specified 0
# Created a chunk of size 742, which is longer than the specified 0
# Created a chunk of size 1293, which is longer than the specified 0
# Created a chunk of size 1382, which is longer than the specified 0
# Created a chunk of size 191, which is longer than the specified 0
# Created a chunk of size 3647, which is longer than the specified 0
# Created a chunk of size 491, which is longer than the specified 0
# Created a chunk of size 882, which is longer than the specified 0
# Created a chunk of size 269, which is longer than the specified 0
# Created a chunk of size 410, which is longer than the specified 0
# Created a chunk of size 670, which is longer than the specified 0
# Created a chunk of size 615, which is longer than the specified 0
# Created a chunk of size 283, which is longer than the specified 0
# Created a chunk of size 782, which is longer than the specified 0
# Created a chunk of size 537, which is longer than the specified 0
# Created a chunk of size 265, which is longer than the specified 0
# Created a chunk of size 453, which is longer than the specified 0
# Created a chunk of size 767, which is longer than the specified 0
# Created a chunk of size 658, which is longer than the specified 0
# Created a chunk of size 276, which is longer than the specified 0
# Created a chunk of size 1096, which is longer than the specified 0
# Created a chunk of size 394, which is longer than the specified 0
# Created a chunk of size 283, which is longer than the specified 0
# Created a chunk of size 472, which is longer than the specified 0
# Created a chunk of size 776, which is longer than the specified 0
# Created a chunk of size 416, which is longer than the specified 0
# Created a chunk of size 300, which is longer than the specified 0
# Created a chunk of size 1295, which is longer than the specified 0
# Created a chunk of size 1047, which is longer than the specified 0
# Created a chunk of size 3955, which is longer than the specified 0
# Created a chunk of size 1362, which is longer than the specified 0
# Created a chunk of size 1543, which is longer than the specified 0
# Created a chunk of size 4683, which is longer than the specified 0
# Created a chunk of size 1113, which is longer than the specified 0
# Created a chunk of size 1395, which is longer than the specified 0
# Created a chunk of size 256, which is longer than the specified 0
# Created a chunk of size 1551, which is longer than the specified 0
# Created a chunk of size 365, which is longer than the specified 0
# Created a chunk of size 207, which is longer than the specified 0
# Created a chunk of size 622, which is longer than the specified 0
# Created a chunk of size 943, which is longer than the specified 0
# Created a chunk of size 639, which is longer than the specified 0
# Created a chunk of size 782, which is longer than the specified 0
# Created a chunk of size 287, which is longer than the specified 0
# Created a chunk of size 400, which is longer than the specified 0
# Created a chunk of size 626, which is longer than the specified 0
# Created a chunk of size 3011, which is longer than the specified 0
# Created a chunk of size 258, which is longer than the specified 0
# Created a chunk of size 599, which is longer than the specified 0
# Created a chunk of size 1551, which is longer than the specified 0
# Created a chunk of size 324, which is longer than the specified 0
# Created a chunk of size 229, which is longer than the specified 0
# Created a chunk of size 899, which is longer than the specified 0
# Created a chunk of size 1374, which is longer than the specified 0
# Created a chunk of size 1280, which is longer than the specified 0
# Created a chunk of size 765, which is longer than the specified 0
# Created a chunk of size 1164, which is longer than the specified 0
# Created a chunk of size 775, which is longer than the specified 0
# Created a chunk of size 1189, which is longer than the specified 0
# Created a chunk of size 359, which is longer than the specified 0
# Created a chunk of size 290, which is longer than the specified 0
# Created a chunk of size 280, which is longer than the specified 0
# Created a chunk of size 271, which is longer than the specified 0
# Created a chunk of size 2223, which is longer than the specified 0
# Created a chunk of size 2985, which is longer than the specified 0
# Created a chunk of size 1134, which is longer than the specified 0
# Created a chunk of size 694, which is longer than the specified 0
# Created a chunk of size 1508, which is longer than the specified 0
# Created a chunk of size 519, which is longer than the specified 0
# Created a chunk of size 644, which is longer than the specified 0
# Created a chunk of size 207, which is longer than the specified 0
# Created a chunk of size 1088, which is longer than the specified 0
# Created a chunk of size 1244, which is longer than the specified 0
# Created a chunk of size 3055, which is longer than the specified 0
# Created a chunk of size 588, which is longer than the specified 0
# Created a chunk of size 359, which is longer than the specified 0
# Created a chunk of size 705, which is longer than the specified 0
# Created a chunk of size 223, which is longer than the specified 0
# Created a chunk of size 2075, which is longer than the specified 0
# Created a chunk of size 1817, which is longer than the specified 0
# Created a chunk of size 264, which is longer than the specified 0
# Created a chunk of size 1762, which is longer than the specified 0
# Created a chunk of size 443, which is longer than the specified 0
# Created a chunk of size 646, which is longer than the specified 0
# Created a chunk of size 961, which is longer than the specified 0
# Created a chunk of size 205, which is longer than the specified 0
# Created a chunk of size 643, which is longer than the specified 0
# Created a chunk of size 500, which is longer than the specified 0
# Created a chunk of size 1027, which is longer than the specified 0
# Created a chunk of size 858, which is longer than the specified 0
# Created a chunk of size 291, which is longer than the specified 0
# Created a chunk of size 629, which is longer than the specified 0
# Created a chunk of size 208, which is longer than the specified 0
# Created a chunk of size 650, which is longer than the specified 0
# Created a chunk of size 1568, which is longer than the specified 0
# Created a chunk of size 1451, which is longer than the specified 0
# Created a chunk of size 1736, which is longer than the specified 0
# Created a chunk of size 2159, which is longer than the specified 0
# Created a chunk of size 1930, which is longer than the specified 0
# Created a chunk of size 797, which is longer than the specified 0
# Created a chunk of size 392, which is longer than the specified 0
# Created a chunk of size 5576, which is longer than the specified 0
# Created a chunk of size 213, which is longer than the specified 0
# Created a chunk of size 1828, which is longer than the specified 0
# Created a chunk of size 236, which is longer than the specified 0
# Created a chunk of size 723, which is longer than the specified 0
# Created a chunk of size 1911, which is longer than the specified 0
# Created a chunk of size 180, which is longer than the specified 0
# Created a chunk of size 869, which is longer than the specified 0
# Created a chunk of size 542, which is longer than the specified 0
# Created a chunk of size 255, which is longer than the specified 0
# Created a chunk of size 1747, which is longer than the specified 0
# Created a chunk of size 546, which is longer than the specified 0
# Created a chunk of size 599, which is longer than the specified 0
# Created a chunk of size 2839, which is longer than the specified 0
# Created a chunk of size 512, which is longer than the specified 0
# Created a chunk of size 1311, which is longer than the specified 0
# Created a chunk of size 400, which is longer than the specified 0
# Created a chunk of size 211, which is longer than the specified 0
# Created a chunk of size 1258, which is longer than the specified 0
# Created a chunk of size 1976, which is longer than the specified 0
# Created a chunk of size 3153, which is longer than the specified 0
# Created a chunk of size 1512, which is longer than the specified 0
# Created a chunk of size 685, which is longer than the specified 0
# Created a chunk of size 1898, which is longer than the specified 0
# Created a chunk of size 719, which is longer than the specified 0
# Created a chunk of size 380, which is longer than the specified 0
# Created a chunk of size 1128, which is longer than the specified 0
# Created a chunk of size 1312, which is longer than the specified 0
# Created a chunk of size 2082, which is longer than the specified 0
# Created a chunk of size 808, which is longer than the specified 0
# Created a chunk of size 585, which is longer than the specified 0
# Created a chunk of size 340, which is longer than the specified 0
# Created a chunk of size 260, which is longer than the specified 0
# Created a chunk of size 953, which is longer than the specified 0
# Created a chunk of size 3020, which is longer than the specified 0
# Created a chunk of size 1821, which is longer than the specified 0
# Created a chunk of size 172, which is longer than the specified 0
# Created a chunk of size 1009, which is longer than the specified 0
# Created a chunk of size 388, which is longer than the specified 0
# Created a chunk of size 418, which is longer than the specified 0
# Created a chunk of size 777, which is longer than the specified 0
# Created a chunk of size 1957, which is longer than the specified 0
# Created a chunk of size 285, which is longer than the specified 0
# Created a chunk of size 1396, which is longer than the specified 0
# Created a chunk of size 740, which is longer than the specified 0
# Created a chunk of size 1405, which is longer than the specified 0
# Created a chunk of size 703, which is longer than the specified 0
# Created a chunk of size 752, which is longer than the specified 0
# Created a chunk of size 1393, which is longer than the specified 0
# Created a chunk of size 1291, which is longer than the specified 0
# Created a chunk of size 1568, which is longer than the specified 0
# Created a chunk of size 646, which is longer than the specified 0
# Created a chunk of size 1646, which is longer than the specified 0
# Created a chunk of size 222, which is longer than the specified 0
# Created a chunk of size 1088, which is longer than the specified 0
# Created a chunk of size 1776, which is longer than the specified 0
# Created a chunk of size 3438, which is longer than the specified 0
# Created a chunk of size 2995, which is longer than the specified 0
# Created a chunk of size 353, which is longer than the specified 0
# Created a chunk of size 560, which is longer than the specified 0
# Created a chunk of size 3130, which is longer than the specified 0
# Created a chunk of size 1493, which is longer than the specified 0
# Created a chunk of size 2381, which is longer than the specified 0
# Created a chunk of size 1104, which is longer than the specified 0
# Created a chunk of size 3123, which is longer than the specified 0
# Created a chunk of size 570, which is longer than the specified 0
# Created a chunk of size 465, which is longer than the specified 0
# Created a chunk of size 834, which is longer than the specified 0
# Created a chunk of size 1291, which is longer than the specified 0
# Created a chunk of size 495, which is longer than the specified 0
# Created a chunk of size 463, which is longer than the specified 0
# Created a chunk of size 2066, which is longer than the specified 0
# Created a chunk of size 702, which is longer than the specified 0
# Created a chunk of size 189, which is longer than the specified 0
# Created a chunk of size 1431, which is longer than the specified 0
# Created a chunk of size 1442, which is longer than the specified 0
# Created a chunk of size 481, which is longer than the specified 0
# Created a chunk of size 740, which is longer than the specified 0
# Created a chunk of size 1831, which is longer than the specified 0
# Created a chunk of size 1215, which is longer than the specified 0
# Created a chunk of size 751, which is longer than the specified 0
# Created a chunk of size 817, which is longer than the specified 0
# Created a chunk of size 1678, which is longer than the specified 0
# Created a chunk of size 2006, which is longer than the specified 0
# Created a chunk of size 488, which is longer than the specified 0
# Created a chunk of size 598, which is longer than the specified 0
# Created a chunk of size 1290, which is longer than the specified 0
# Created a chunk of size 1632, which is longer than the specified 0
# Created a chunk of size 776, which is longer than the specified 0
# Created a chunk of size 803, which is longer than the specified 0
# Created a chunk of size 3014, which is longer than the specified 0
# Created a chunk of size 824, which is longer than the specified 0
# Created a chunk of size 680, which is longer than the specified 0
# Created a chunk of size 326, which is longer than the specified 0
# Created a chunk of size 933, which is longer than the specified 0
# Created a chunk of size 876, which is longer than the specified 0
# Created a chunk of size 1574, which is longer than the specified 0
# Created a chunk of size 1404, which is longer than the specified 0
# Created a chunk of size 2426, which is longer than the specified 0
# Created a chunk of size 888, which is longer than the specified 0
# Created a chunk of size 486, which is longer than the specified 0
# Created a chunk of size 423, which is longer than the specified 0
# Created a chunk of size 1328, which is longer than the specified 0
# Created a chunk of size 728, which is longer than the specified 0
# Created a chunk of size 508, which is longer than the specified 0
# Created a chunk of size 770, which is longer than the specified 0
# Created a chunk of size 452, which is longer than the specified 0
# Created a chunk of size 538, which is longer than the specified 0
# Created a chunk of size 2437, which is longer than the specified 0
# Created a chunk of size 2227, which is longer than the specified 0
# Created a chunk of size 440, which is longer than the specified 0
# Created a chunk of size 817, which is longer than the specified 0
# Created a chunk of size 840, which is longer than the specified 0
# Created a chunk of size 3258, which is longer than the specified 0
# Created a chunk of size 1267, which is longer than the specified 0
# Created a chunk of size 833, which is longer than the specified 0
# Created a chunk of size 819, which is longer than the specified 0
# Created a chunk of size 1489, which is longer than the specified 0
# Created a chunk of size 684, which is longer than the specified 0
# Created a chunk of size 650, which is longer than the specified 0
# Created a chunk of size 736, which is longer than the specified 0
# Created a chunk of size 574, which is longer than the specified 0
# Created a chunk of size 595, which is longer than the specified 0
# Created a chunk of size 899, which is longer than the specified 0
# Created a chunk of size 3360, which is longer than the specified 0
# Created a chunk of size 981, which is longer than the specified 0
# Created a chunk of size 1060, which is longer than the specified 0
# Created a chunk of size 972, which is longer than the specified 0
# Created a chunk of size 706, which is longer than the specified 0
# Created a chunk of size 1182, which is longer than the specified 0
# Created a chunk of size 720, which is longer than the specified 0
# Created a chunk of size 945, which is longer than the specified 0
# Created a chunk of size 972, which is longer than the specified 0
# Created a chunk of size 765, which is longer than the specified 0
# Created a chunk of size 907, which is longer than the specified 0
# Created a chunk of size 897, which is longer than the specified 0
# Created a chunk of size 832, which is longer than the specified 0
# Created a chunk of size 2707, which is longer than the specified 0
# Created a chunk of size 1659, which is longer than the specified 0
# Created a chunk of size 1699, which is longer than the specified 0
# Created a chunk of size 1357, which is longer than the specified 0
# Created a chunk of size 1598, which is longer than the specified 0
# Created a chunk of size 1580, which is longer than the specified 0
# Created a chunk of size 1408, which is longer than the specified 0
# Created a chunk of size 1003, which is longer than the specified 0
# Created a chunk of size 449, which is longer than the specified 0
# Created a chunk of size 3038, which is longer than the specified 0
# Created a chunk of size 646, which is longer than the specified 0
# Created a chunk of size 883, which is longer than the specified 0
# Created a chunk of size 952, which is longer than the specified 0
# Created a chunk of size 403, which is longer than the specified 0
# Created a chunk of size 2777, which is longer than the specified 0
# Created a chunk of size 1433, which is longer than the specified 0
# Created a chunk of size 943, which is longer than the specified 0
# Created a chunk of size 586, which is longer than the specified 0
# Created a chunk of size 555, which is longer than the specified 0
# Created a chunk of size 1387, which is longer than the specified 0
# Created a chunk of size 1437, which is longer than the specified 0
# Created a chunk of size 659, which is longer than the specified 0
# Created a chunk of size 2904, which is longer than the specified 0
# Created a chunk of size 975, which is longer than the specified 0
# Created a chunk of size 1674, which is longer than the specified 0
# Created a chunk of size 1554, which is longer than the specified 0
# Created a chunk of size 1389, which is longer than the specified 0
# Created a chunk of size 799, which is longer than the specified 0
# Created a chunk of size 834, which is longer than the specified 0
# Created a chunk of size 1850, which is longer than the specified 0
# Created a chunk of size 761, which is longer than the specified 0
# Created a chunk of size 1117, which is longer than the specified 0
# Created a chunk of size 816, which is longer than the specified 0
# Created a chunk of size 881, which is longer than the specified 0
# Created a chunk of size 472, which is longer than the specified 0
# Created a chunk of size 970, which is longer than the specified 0
# Created a chunk of size 1579, which is longer than the specified 0
# Created a chunk of size 1101, which is longer than the specified 0
# Created a chunk of size 790, which is longer than the specified 0
# Created a chunk of size 905, which is longer than the specified 0
# Created a chunk of size 1228, which is longer than the specified 0
# Created a chunk of size 964, which is longer than the specified 0
# Created a chunk of size 1260, which is longer than the specified 0
# Created a chunk of size 417, which is longer than the specified 0
# Created a chunk of size 1610, which is longer than the specified 0
# Created a chunk of size 1195, which is longer than the specified 0
# Created a chunk of size 1379, which is longer than the specified 0
# Created a chunk of size 1318, which is longer than the specified 0
# Created a chunk of size 265, which is longer than the specified 0
# Created a chunk of size 1022, which is longer than the specified 0
# Created a chunk of size 1647, which is longer than the specified 0
# Created a chunk of size 1215, which is longer than the specified 0
# Created a chunk of size 216, which is longer than the specified 0
# Created a chunk of size 2094, which is longer than the specified 0
# Created a chunk of size 1327, which is longer than the specified 0
# Created a chunk of size 575, which is longer than the specified 0
# Created a chunk of size 697, which is longer than the specified 0
# Created a chunk of size 1010, which is longer than the specified 0
# Created a chunk of size 598, which is longer than the specified 0
# Created a chunk of size 2719, which is longer than the specified 0
# Created a chunk of size 662, which is longer than the specified 0
# Created a chunk of size 990, which is longer than the specified 0
# Created a chunk of size 576, which is longer than the specified 0
# Created a chunk of size 4632, which is longer than the specified 0
# Created a chunk of size 689, which is longer than the specified 0
# Created a chunk of size 759, which is longer than the specified 0
# Created a chunk of size 1174, which is longer than the specified 0
# Created a chunk of size 1140, which is longer than the specified 0
# Created a chunk of size 1078, which is longer than the specified 0
# Created a chunk of size 2046, which is longer than the specified 0
# Created a chunk of size 703, which is longer than the specified 0
# Created a chunk of size 464, which is longer than the specified 0
# Created a chunk of size 2243, which is longer than the specified 0
# Created a chunk of size 514, which is longer than the specified 0
# Created a chunk of size 2066, which is longer than the specified 0
# Created a chunk of size 960, which is longer than the specified 0
# Created a chunk of size 924, which is longer than the specified 0
# Created a chunk of size 1050, which is longer than the specified 0
# Created a chunk of size 3493, which is longer than the specified 0
# Created a chunk of size 1235, which is longer than the specified 0
# Created a chunk of size 1959, which is longer than the specified 0
# Created a chunk of size 1045, which is longer than the specified 0
# Created a chunk of size 790, which is longer than the specified 0
# Created a chunk of size 1337, which is longer than the specified 0
# Created a chunk of size 1488, which is longer than the specified 0
# Created a chunk of size 1421, which is longer than the specified 0
# Created a chunk of size 939, which is longer than the specified 0
# Created a chunk of size 672, which is longer than the specified 0
# Created a chunk of size 1056, which is longer than the specified 0
# Created a chunk of size 1521, which is longer than the specified 0
# Created a chunk of size 3962, which is longer than the specified 0
# Created a chunk of size 1150, which is longer than the specified 0
# Created a chunk of size 427, which is longer than the specified 0
# Created a chunk of size 1173, which is longer than the specified 0
# Created a chunk of size 1475, which is longer than the specified 0
# Created a chunk of size 794, which is longer than the specified 0
# Created a chunk of size 2210, which is longer than the specified 0
# Created a chunk of size 1188, which is longer than the specified 0
# Created a chunk of size 1066, which is longer than the specified 0
# Created a chunk of size 1223, which is longer than the specified 0
# Created a chunk of size 663, which is longer than the specified 0
# Created a chunk of size 1122, which is longer than the specified 0
# Created a chunk of size 1205, which is longer than the specified 0
# Created a chunk of size 708, which is longer than the specified 0
# Created a chunk of size 2611, which is longer than the specified 0
# Created a chunk of size 1140, which is longer than the specified 0
# Created a chunk of size 863, which is longer than the specified 0
# Created a chunk of size 1291, which is longer than the specified 0
# Created a chunk of size 2451, which is longer than the specified 0
# Created a chunk of size 2541, which is longer than the specified 0
# Created a chunk of size 835, which is longer than the specified 0
# Created a chunk of size 2019, which is longer than the specified 0
# Created a chunk of size 650, which is longer than the specified 0
# Created a chunk of size 411, which is longer than the specified 0
# Created a chunk of size 502, which is longer than the specified 0
# Created a chunk of size 575, which is longer than the specified 0
# Created a chunk of size 1076, which is longer than the specified 0
# Created a chunk of size 3386, which is longer than the specified 0
# Created a chunk of size 1486, which is longer than the specified 0
# Created a chunk of size 1500, which is longer than the specified 0
# Created a chunk of size 1756, which is longer than the specified 0
# Created a chunk of size 1281, which is longer than the specified 0
# Created a chunk of size 533, which is longer than the specified 0
# Created a chunk of size 873, which is longer than the specified 0
# Created a chunk of size 508, which is longer than the specified 0
# Created a chunk of size 3489, which is longer than the specified 0
# Created a chunk of size 2214, which is longer than the specified 0
# Created a chunk of size 1353, which is longer than the specified 0
# Created a chunk of size 608, which is longer than the specified 0
# Created a chunk of size 313, which is longer than the specified 0
# Created a chunk of size 470, which is longer than the specified 0
# Created a chunk of size 589, which is longer than the specified 0
# Created a chunk of size 971, which is longer than the specified 0
# Created a chunk of size 2449, which is longer than the specified 0
# Created a chunk of size 2635, which is longer than the specified 0
# Created a chunk of size 1662, which is longer than the specified 0
# Created a chunk of size 1340, which is longer than the specified 0
# Created a chunk of size 930, which is longer than the specified 0
# Created a chunk of size 1611, which is longer than the specified 0
# Created a chunk of size 734, which is longer than the specified 0
# Created a chunk of size 1481, which is longer than the specified 0
# Created a chunk of size 748, which is longer than the specified 0
# Created a chunk of size 1110, which is longer than the specified 0
# Created a chunk of size 1930, which is longer than the specified 0
# Created a chunk of size 1421, which is longer than the specified 0
# Created a chunk of size 815, which is longer than the specified 0
# Created a chunk of size 260, which is longer than the specified 0
# Created a chunk of size 2747, which is longer than the specified 0
# Created a chunk of size 1276, which is longer than the specified 0
# Created a chunk of size 783, which is longer than the specified 0
# Created a chunk of size 835, which is longer than the specified 0
# Created a chunk of size 1710, which is longer than the specified 0
# Created a chunk of size 1554, which is longer than the specified 0
# Created a chunk of size 978, which is longer than the specified 0
# Created a chunk of size 2387, which is longer than the specified 0
# Created a chunk of size 4055, which is longer than the specified 0
# Created a chunk of size 497, which is longer than the specified 0
# Created a chunk of size 882, which is longer than the specified 0
# Created a chunk of size 412, which is longer than the specified 0
# Created a chunk of size 751, which is longer than the specified 0
# Created a chunk of size 1684, which is longer than the specified 0
# Created a chunk of size 2293, which is longer than the specified 0
# Created a chunk of size 722, which is longer than the specified 0
# Created a chunk of size 220, which is longer than the specified 0
# Created a chunk of size 724, which is longer than the specified 0
# Created a chunk of size 2491, which is longer than the specified 0
# Created a chunk of size 2409, which is longer than the specified 0
# Created a chunk of size 1009, which is longer than the specified 0
# Created a chunk of size 519, which is longer than the specified 0
# Created a chunk of size 612, which is longer than the specified 0
# Created a chunk of size 712, which is longer than the specified 0
# Created a chunk of size 268, which is longer than the specified 0
# Created a chunk of size 726, which is longer than the specified 0
# Created a chunk of size 1517, which is longer than the specified 0
# Created a chunk of size 3621, which is longer than the specified 0
# Created a chunk of size 410, which is longer than the specified 0
# Created a chunk of size 424, which is longer than the specified 0
# Created a chunk of size 785, which is longer than the specified 0
# Created a chunk of size 2058, which is longer than the specified 0
# Created a chunk of size 379, which is longer than the specified 0
# Created a chunk of size 417, which is longer than the specified 0
# Created a chunk of size 344, which is longer than the specified 0
# Created a chunk of size 1128, which is longer than the specified 0
# Created a chunk of size 244, which is longer than the specified 0
# Created a chunk of size 1429, which is longer than the specified 0
# Created a chunk of size 746, which is longer than the specified 0
# Created a chunk of size 3518, which is longer than the specified 0
# Created a chunk of size 1251, which is longer than the specified 0
# Created a chunk of size 1521, which is longer than the specified 0
# Created a chunk of size 1923, which is longer than the specified 0
# Created a chunk of size 1720, which is longer than the specified 0
# Created a chunk of size 3871, which is longer than the specified 0
# Created a chunk of size 1469, which is longer than the specified 0
# Created a chunk of size 1251, which is longer than the specified 0
# Created a chunk of size 1014, which is longer than the specified 0
# Created a chunk of size 986, which is longer than the specified 0
# Created a chunk of size 221, which is longer than the specified 0
# Created a chunk of size 194, which is longer than the specified 0
# Created a chunk of size 2809, which is longer than the specified 0
# Created a chunk of size 844, which is longer than the specified 0
# Created a chunk of size 2991, which is longer than the specified 0
# Created a chunk of size 490, which is longer than the specified 0
# Created a chunk of size 557, which is longer than the specified 0
# Created a chunk of size 703, which is longer than the specified 0
# Created a chunk of size 425, which is longer than the specified 0
# Created a chunk of size 1346, which is longer than the specified 0
# Created a chunk of size 901, which is longer than the specified 0
# Created a chunk of size 254, which is longer than the specified 0
# Created a chunk of size 2523, which is longer than the specified 0
# Created a chunk of size 187, which is longer than the specified 0
# Created a chunk of size 3370, which is longer than the specified 0
# Created a chunk of size 2078, which is longer than the specified 0
# Created a chunk of size 3077, which is longer than the specified 0
# Created a chunk of size 3464, which is longer than the specified 0
# Created a chunk of size 2103, which is longer than the specified 0
# Created a chunk of size 1035, which is longer than the specified 0
# Created a chunk of size 1033, which is longer than the specified 0
# Created a chunk of size 3284, which is longer than the specified 0
# Created a chunk of size 1920, which is longer than the specified 0
# Created a chunk of size 3710, which is longer than the specified 0
# Created a chunk of size 4050, which is longer than the specified 0
# Created a chunk of size 912, which is longer than the specified 0
# Created a chunk of size 3142, which is longer than the specified 0
# Created a chunk of size 469, which is longer than the specified 0
# Created a chunk of size 2720, which is longer than the specified 0
# Created a chunk of size 851, which is longer than the specified 0
# Created a chunk of size 3284, which is longer than the specified 0
# Created a chunk of size 1557, which is longer than the specified 0
# Created a chunk of size 517, which is longer than the specified 0
# Created a chunk of size 248, which is longer than the specified 0
# Created a chunk of size 471, which is longer than the specified 0
# Created a chunk of size 1897, which is longer than the specified 0
# Created a chunk of size 628, which is longer than the specified 0
# Created a chunk of size 4138, which is longer than the specified 0
# Created a chunk of size 4557, which is longer than the specified 0
# Created a chunk of size 3301, which is longer than the specified 0
# Created a chunk of size 2848, which is longer than the specified 0
# Created a chunk of size 2606, which is longer than the specified 0
# Created a chunk of size 409, which is longer than the specified 0
# Created a chunk of size 561, which is longer than the specified 0
# Created a chunk of size 432, which is longer than the specified 0
# Created a chunk of size 1350, which is longer than the specified 0
# Created a chunk of size 1388, which is longer than the specified 0
# Created a chunk of size 370, which is longer than the specified 0
# Created a chunk of size 279, which is longer than the specified 0
# Created a chunk of size 796, which is longer than the specified 0
# Created a chunk of size 1837, which is longer than the specified 0
# Created a chunk of size 1060, which is longer than the specified 0
# Created a chunk of size 337, which is longer than the specified 0
# Created a chunk of size 465, which is longer than the specified 0
# Created a chunk of size 729, which is longer than the specified 0
# Created a chunk of size 2203, which is longer than the specified 0
# Created a chunk of size 2066, which is longer than the specified 0
# Created a chunk of size 541, which is longer than the specified 0
# Created a chunk of size 4035, which is longer than the specified 0
# Created a chunk of size 266, which is longer than the specified 0
# Created a chunk of size 3112, which is longer than the specified 0
# Created a chunk of size 771, which is longer than the specified 0
# Created a chunk of size 606, which is longer than the specified 0
# Created a chunk of size 1146, which is longer than the specified 0
# Created a chunk of size 3365, which is longer than the specified 0
# Created a chunk of size 280, which is longer than the specified 0
# Created a chunk of size 428, which is longer than the specified 0
# Created a chunk of size 1670, which is longer than the specified 0
# Created a chunk of size 320, which is longer than the specified 0
# Created a chunk of size 1065, which is longer than the specified 0
# Created a chunk of size 899, which is longer than the specified 0
# Created a chunk of size 6060, which is longer than the specified 0
# Created a chunk of size 1400, which is longer than the specified 0
# Created a chunk of size 953, which is longer than the specified 0
# Created a chunk of size 2967, which is longer than the specified 0
# Created a chunk of size 3494, which is longer than the specified 0
# Created a chunk of size 3962, which is longer than the specified 0
# Created a chunk of size 456, which is longer than the specified 0
# Created a chunk of size 1184, which is longer than the specified 0
# Created a chunk of size 437, which is longer than the specified 0
# Created a chunk of size 3812, which is longer than the specified 0
# Created a chunk of size 2812, which is longer than the specified 0
# Created a chunk of size 3845, which is longer than the specified 0
# Created a chunk of size 828, which is longer than the specified 0
# Created a chunk of size 1224, which is longer than the specified 0
# Created a chunk of size 845, which is longer than the specified 0
# Created a chunk of size 1403, which is longer than the specified 0
# Created a chunk of size 349, which is longer than the specified 0
# Created a chunk of size 918, which is longer than the specified 0
# Created a chunk of size 256, which is longer than the specified 0
# Created a chunk of size 817, which is longer than the specified 0
# Created a chunk of size 8221, which is longer than the specified 0
# Created a chunk of size 1292, which is longer than the specified 0
# Created a chunk of size 226, which is longer than the specified 0
# Created a chunk of size 185, which is longer than the specified 0
# Created a chunk of size 360, which is longer than the specified 0
# Created a chunk of size 1161, which is longer than the specified 0
# Created a chunk of size 3700, which is longer than the specified 0
# Created a chunk of size 2203, which is longer than the specified 0
# Created a chunk of size 970, which is longer than the specified 0
# Created a chunk of size 827, which is longer than the specified 0
# Created a chunk of size 172, which is longer than the specified 0
# Created a chunk of size 632, which is longer than the specified 0
# Created a chunk of size 217, which is longer than the specified 0
# Created a chunk of size 646, which is longer than the specified 0
# Created a chunk of size 209, which is longer than the specified 0
# Created a chunk of size 863, which is longer than the specified 0
# Created a chunk of size 490, which is longer than the specified 0
# Created a chunk of size 2601, which is longer than the specified 0
# Created a chunk of size 3953, which is longer than the specified 0
# Created a chunk of size 834, which is longer than the specified 0
# Created a chunk of size 670, which is longer than the specified 0
# Created a chunk of size 1750, which is longer than the specified 0
# Created a chunk of size 3621, which is longer than the specified 0
# Created a chunk of size 363, which is longer than the specified 0
# Created a chunk of size 4033, which is longer than the specified 0
# Created a chunk of size 1350, which is longer than the specified 0
# Created a chunk of size 1052, which is longer than the specified 0
# Created a chunk of size 2457, which is longer than the specified 0
# Created a chunk of size 3051, which is longer than the specified 0
# Created a chunk of size 3979, which is longer than the specified 0
# Created a chunk of size 1076, which is longer than the specified 0
# Created a chunk of size 1404, which is longer than the specified 0
# Created a chunk of size 912, which is longer than the specified 0
# Created a chunk of size 236, which is longer than the specified 0
# Created a chunk of size 1187, which is longer than the specified 0
# Created a chunk of size 1380, which is longer than the specified 0
# Created a chunk of size 358, which is longer than the specified 0
# Created a chunk of size 620, which is longer than the specified 0
# Created a chunk of size 1446, which is longer than the specified 0
# Created a chunk of size 2025, which is longer than the specified 0
# Created a chunk of size 4498, which is longer than the specified 0
# Created a chunk of size 305, which is longer than the specified 0
# Created a chunk of size 525, which is longer than the specified 0
# Created a chunk of size 383, which is longer than the specified 0
# Created a chunk of size 543, which is longer than the specified 0
# Created a chunk of size 381, which is longer than the specified 0
# Created a chunk of size 2901, which is longer than the specified 0
# Created a chunk of size 4202, which is longer than the specified 0
# Created a chunk of size 2641, which is longer than the specified 0
# Created a chunk of size 1622, which is longer than the specified 0
# Created a chunk of size 2969, which is longer than the specified 0
# Created a chunk of size 848, which is longer than the specified 0
# Created a chunk of size 700, which is longer than the specified 0
# Created a chunk of size 403, which is longer than the specified 0
# Created a chunk of size 858, which is longer than the specified 0
# Created a chunk of size 978, which is longer than the specified 0
# Created a chunk of size 2163, which is longer than the specified 0
# Created a chunk of size 680, which is longer than the specified 0
# Created a chunk of size 792, which is longer than the specified 0
# Created a chunk of size 2538, which is longer than the specified 0
# Created a chunk of size 408, which is longer than the specified 0
# Created a chunk of size 4415, which is longer than the specified 0
# Created a chunk of size 2670, which is longer than the specified 0
# Created a chunk of size 223, which is longer than the specified 0
# Created a chunk of size 553, which is longer than the specified 0
# Created a chunk of size 420, which is longer than the specified 0
# Created a chunk of size 453, which is longer than the specified 0
# Created a chunk of size 3462, which is longer than the specified 0
# Created a chunk of size 652, which is longer than the specified 0
# Created a chunk of size 840, which is longer than the specified 0
# Created a chunk of size 1890, which is longer than the specified 0
# Created a chunk of size 1724, which is longer than the specified 0
# Created a chunk of size 438, which is longer than the specified 0
# Created a chunk of size 385, which is longer than the specified 0
# Created a chunk of size 1506, which is longer than the specified 0
# Created a chunk of size 1063, which is longer than the specified 0
# Created a chunk of size 428, which is longer than the specified 0
# Created a chunk of size 203, which is longer than the specified 0
# Created a chunk of size 641, which is longer than the specified 0
# Created a chunk of size 640, which is longer than the specified 0
# Created a chunk of size 1015, which is longer than the specified 0
# Created a chunk of size 680, which is longer than the specified 0
# Created a chunk of size 2348, which is longer than the specified 0
# Created a chunk of size 4768, which is longer than the specified 0
# Created a chunk of size 2579, which is longer than the specified 0
# Created a chunk of size 4273, which is longer than the specified 0
# Created a chunk of size 764, which is longer than the specified 0
# Created a chunk of size 1833, which is longer than the specified 0
# Created a chunk of size 623, which is longer than the specified 0
# Created a chunk of size 6996, which is longer than the specified 0
# Created a chunk of size 2961, which is longer than the specified 0
# Created a chunk of size 292, which is longer than the specified 0
# Created a chunk of size 397, which is longer than the specified 0
# Created a chunk of size 3712, which is longer than the specified 0
# Created a chunk of size 3053, which is longer than the specified 0
# Created a chunk of size 2956, which is longer than the specified 0
# Created a chunk of size 2652, which is longer than the specified 0
# Created a chunk of size 2663, which is longer than the specified 0
# Created a chunk of size 3059, which is longer than the specified 0
# Created a chunk of size 676, which is longer than the specified 0
# Created a chunk of size 2301, which is longer than the specified 0
# Created a chunk of size 1629, which is longer than the specified 0
# Created a chunk of size 965, which is longer than the specified 0
# Created a chunk of size 1953, which is longer than the specified 0
# Created a chunk of size 2272, which is longer than the specified 0
# Created a chunk of size 430, which is longer than the specified 0
# Created a chunk of size 335, which is longer than the specified 0
# Created a chunk of size 1569, which is longer than the specified 0
# Created a chunk of size 684, which is longer than the specified 0
# Created a chunk of size 2408, which is longer than the specified 0
# Created a chunk of size 467, which is longer than the specified 0
# Created a chunk of size 788, which is longer than the specified 0
# Created a chunk of size 678, which is longer than the specified 0
# Created a chunk of size 3139, which is longer than the specified 0
# Created a chunk of size 2091, which is longer than the specified 0
# Created a chunk of size 241, which is longer than the specified 0
# Created a chunk of size 2361, which is longer than the specified 0
# Created a chunk of size 281, which is longer than the specified 0
# Created a chunk of size 2799, which is longer than the specified 0
# Created a chunk of size 515, which is longer than the specified 0
# Created a chunk of size 3568, which is longer than the specified 0
# Created a chunk of size 1927, which is longer than the specified 0
# Created a chunk of size 637, which is longer than the specified 0
# Created a chunk of size 315, which is longer than the specified 0
# Created a chunk of size 426, which is longer than the specified 0
# Created a chunk of size 525, which is longer than the specified 0
# Created a chunk of size 189, which is longer than the specified 0
# Created a chunk of size 749, which is longer than the specified 0
# Created a chunk of size 538, which is longer than the specified 0
# Created a chunk of size 597, which is longer than the specified 0
# Created a chunk of size 4050, which is longer than the specified 0
# Created a chunk of size 2449, which is longer than the specified 0
# Created a chunk of size 638, which is longer than the specified 0
# Created a chunk of size 1253, which is longer than the specified 0
# Created a chunk of size 2027, which is longer than the specified 0
# Created a chunk of size 2562, which is longer than the specified 0
# Created a chunk of size 240, which is longer than the specified 0
# Created a chunk of size 2674, which is longer than the specified 0
# Created a chunk of size 3115, which is longer than the specified 0
# Created a chunk of size 2378, which is longer than the specified 0
# Created a chunk of size 296, which is longer than the specified 0
# Created a chunk of size 1247, which is longer than the specified 0
# Created a chunk of size 2845, which is longer than the specified 0
# Created a chunk of size 780, which is longer than the specified 0
# Created a chunk of size 426, which is longer than the specified 0
# Created a chunk of size 305, which is longer than the specified 0
# Created a chunk of size 292, which is longer than the specified 0
# Created a chunk of size 1565, which is longer than the specified 0
# Created a chunk of size 2504, which is longer than the specified 0
# Created a chunk of size 2303, which is longer than the specified 0
# Created a chunk of size 671, which is longer than the specified 0
# Created a chunk of size 2434, which is longer than the specified 0
# Created a chunk of size 707, which is longer than the specified 0
# Created a chunk of size 3712, which is longer than the specified 0
# Created a chunk of size 172, which is longer than the specified 0
# Created a chunk of size 1641, which is longer than the specified 0
# Created a chunk of size 1015, which is longer than the specified 0
# Created a chunk of size 286, which is longer than the specified 0
# Created a chunk of size 232, which is longer than the specified 0
# Created a chunk of size 3835, which is longer than the specified 0
# Created a chunk of size 254, which is longer than the specified 0
# Created a chunk of size 794, which is longer than the specified 0
# Created a chunk of size 854, which is longer than the specified 0
# Created a chunk of size 1244, which is longer than the specified 0
# Created a chunk of size 243, which is longer than the specified 0
# Created a chunk of size 773, which is longer than the specified 0
# Created a chunk of size 259, which is longer than the specified 0
# Created a chunk of size 3022, which is longer than the specified 0
# Created a chunk of size 1505, which is longer than the specified 0
# Created a chunk of size 262, which is longer than the specified 0
# Created a chunk of size 353, which is longer than the specified 0
# Created a chunk of size 263, which is longer than the specified 0
# Created a chunk of size 502, which is longer than the specified 0
# Created a chunk of size 457, which is longer than the specified 0
# Created a chunk of size 387, which is longer than the specified 0
# Created a chunk of size 2238, which is longer than the specified 0
# Created a chunk of size 1259, which is longer than the specified 0
# Created a chunk of size 1966, which is longer than the specified 0
# Created a chunk of size 2459, which is longer than the specified 0
# Created a chunk of size 2282, which is longer than the specified 0
# Created a chunk of size 180, which is longer than the specified 0
# Created a chunk of size 3067, which is longer than the specified 0
# Created a chunk of size 519, which is longer than the specified 0
# Created a chunk of size 894, which is longer than the specified 0
# Created a chunk of size 3893, which is longer than the specified 0
# Created a chunk of size 2120, which is longer than the specified 0
# Created a chunk of size 1635, which is longer than the specified 0
# Created a chunk of size 785, which is longer than the specified 0
# Created a chunk of size 2493, which is longer than the specified 0
# Created a chunk of size 370, which is longer than the specified 0
# Created a chunk of size 791, which is longer than the specified 0
# Created a chunk of size 1414, which is longer than the specified 0
# Created a chunk of size 967, which is longer than the specified 0
# Created a chunk of size 862, which is longer than the specified 0
# ...
# Created a chunk of size 757, which is longer than the specified 0
# Created a chunk of size 558, which is longer than the specified 0
# Created a chunk of size 1405, which is longer than the specified 0
# Created a chunk of size 1487, which is longer than the specified 0
# Created a chunk of size 382, which is longer than the specified 0
# Created a chunk of size 1139, which is longer than the specified 0
# Created a chunk of size 1145, which is longer than the specified 0
# Created a chunk of size 1006, which is longer than the specified 0
# Created a chunk of size 1336, which is longer than the specified 0
# Created a chunk of size 1702, which is longer than the specified 0
# Created a chunk of size 2106, which is longer than the specified 0
# Created a chunk of size 793, which is longer than the specified 0
# Created a chunk of size 1192, which is longer than the specified 0
# Created a chunk of size 2854, which is longer than the specified 0
# Created a chunk of size 829, which is longer than the specified 0
# Created a chunk of size 1240, which is longer than the specified 0
# Created a chunk of size 1027, which is longer than the specified 0
# Created a chunk of size 1026, which is longer than the specified 0
# Created a chunk of size 1437, which is longer than the specified 0
# Created a chunk of size 3131, which is longer than the specified 0
# Created a chunk of size 884, which is longer than the specified 0
# Created a chunk of size 512, which is longer than the specified 0
# Created a chunk of size 1560, which is longer than the specified 0
# Created a chunk of size 1275, which is longer than the specified 0
# Created a chunk of size 1341, which is longer than the specified 0
# Created a chunk of size 1752, which is longer than the specified 0
# Created a chunk of size 916, which is longer than the specified 0
# Created a chunk of size 555, which is longer than the specified 0
# Created a chunk of size 1133, which is longer than the specified 0
# Created a chunk of size 721, which is longer than the specified 0
# Created a chunk of size 3983, which is longer than the specified 0
# Created a chunk of size 633, which is longer than the specified 0
# Created a chunk of size 1537, which is longer than the specified 0
# Created a chunk of size 388, which is longer than the specified 0
# Created a chunk of size 3125, which is longer than the specified 0
# Created a chunk of size 2494, which is longer than the specified 0
# Created a chunk of size 3238, which is longer than the specified 0
# Created a chunk of size 1151, which is longer than the specified 0
# Created a chunk of size 1093, which is longer than the specified 0
# Created a chunk of size 994, which is longer than the specified 0
# Created a chunk of size 1319, which is longer than the specified 0
# Created a chunk of size 1259, which is longer than the specified 0
# Created a chunk of size 755, which is longer than the specified 0
# Created a chunk of size 508, which is longer than the specified 0
# Created a chunk of size 1363, which is longer than the specified 0
# Created a chunk of size 1526, which is longer than the specified 0
# Created a chunk of size 4591, which is longer than the specified 0
# Created a chunk of size 384, which is longer than the specified 0
# Created a chunk of size 794, which is longer than the specified 0
# Created a chunk of size 411, which is longer than the specified 0
# Created a chunk of size 974, which is longer than the specified 0
# Created a chunk of size 574, which is longer than the specified 0
# Created a chunk of size 636, which is longer than the specified 0
# Created a chunk of size 734, which is longer than the specified 0
# Created a chunk of size 3214, which is longer than the specified 0
# Created a chunk of size 714, which is longer than the specified 0
# Created a chunk of size 942, which is longer than the specified 0
# Created a chunk of size 364, which is longer than the specified 0
# Created a chunk of size 278, which is longer than the specified 0
# Created a chunk of size 470, which is longer than the specified 0
# Created a chunk of size 349, which is longer than the specified 0
# Created a chunk of size 2259, which is longer than the specified 0
# Created a chunk of size 630, which is longer than the specified 0
# Created a chunk of size 473, which is longer than the specified 0
# Created a chunk of size 1385, which is longer than the specified 0
# Created a chunk of size 1122, which is longer than the specified 0
# Created a chunk of size 299, which is longer than the specified 0
# Created a chunk of size 923, which is longer than the specified 0
# Created a chunk of size 3486, which is longer than the specified 0
# Created a chunk of size 496, which is longer than the specified 0
# Created a chunk of size 292, which is longer than the specified 0
# Created a chunk of size 2514, which is longer than the specified 0
# Created a chunk of size 933, which is longer than the specified 0
# Created a chunk of size 672, which is longer than the specified 0
# Created a chunk of size 213, which is longer than the specified 0
# Created a chunk of size 383, which is longer than the specified 0
# Created a chunk of size 2288, which is longer than the specified 0
# Created a chunk of size 695, which is longer than the specified 0
# Created a chunk of size 715, which is longer than the specified 0
# Created a chunk of size 215, which is longer than the specified 0
# Created a chunk of size 834, which is longer than the specified 0
# Created a chunk of size 461, which is longer than the specified 0
# Created a chunk of size 781, which is longer than the specified 0
# Created a chunk of size 402, which is longer than the specified 0
# Created a chunk of size 570, which is longer than the specified 0
# Created a chunk of size 625, which is longer than the specified 0
# Created a chunk of size 681, which is longer than the specified 0
# Created a chunk of size 6006, which is longer than the specified 0
# Created a chunk of size 1015, which is longer than the specified 0
# Created a chunk of size 488, which is longer than the specified 0
# Created a chunk of size 565, which is longer than the specified 0
# Created a chunk of size 940, which is longer than the specified 0
# Created a chunk of size 209, which is longer than the specified 0
# Created a chunk of size 1275, which is longer than the specified 0
# Created a chunk of size 4221, which is longer than the specified 0
# Created a chunk of size 363, which is longer than the specified 0
# Created a chunk of size 669, which is longer than the specified 0
# Created a chunk of size 2278, which is longer than the specified 0
# Created a chunk of size 2174, which is longer than the specified 0
# Created a chunk of size 386, which is longer than the specified 0
# Created a chunk of size 697, which is longer than the specified 0
# Created a chunk of size 1189, which is longer than the specified 0
# Created a chunk of size 3818, which is longer than the specified 0
# Created a chunk of size 3969, which is longer than the specified 0
# Created a chunk of size 412, which is longer than the specified 0
# Created a chunk of size 402, which is longer than the specified 0
# Created a chunk of size 1558, which is longer than the specified 0
# Created a chunk of size 522, which is longer than the specified 0
# Created a chunk of size 533, which is longer than the specified 0
# Created a chunk of size 189, which is longer than the specified 0
# Created a chunk of size 827, which is longer than the specified 0
# Created a chunk of size 4447, which is longer than the specified 0
# Created a chunk of size 972, which is longer than the specified 0
# Created a chunk of size 557, which is longer than the specified 0
# Created a chunk of size 351, which is longer than the specified 0
# Created a chunk of size 4578, which is longer than the specified 0
# Created a chunk of size 1090, which is longer than the specified 0
# Created a chunk of size 338, which is longer than the specified 0
# Created a chunk of size 1286, which is longer than the specified 0
# Created a chunk of size 811, which is longer than the specified 0
# Created a chunk of size 312, which is longer than the specified 0
# Created a chunk of size 525, which is longer than the specified 0
# Created a chunk of size 594, which is longer than the specified 0
# Created a chunk of size 483, which is longer than the specified 0
# Created a chunk of size 1877, which is longer than the specified 0
# Created a chunk of size 362, which is longer than the specified 0
# Created a chunk of size 1233, which is longer than the specified 0
# Created a chunk of size 3432, which is longer than the specified 0
# Created a chunk of size 518, which is longer than the specified 0
# Created a chunk of size 713, which is longer than the specified 0
# Created a chunk of size 523, which is longer than the specified 0
# Created a chunk of size 816, which is longer than the specified 0
# Created a chunk of size 1484, which is longer than the specified 0
# Created a chunk of size 3799, which is longer than the specified 0
# Created a chunk of size 4231, which is longer than the specified 0
# Created a chunk of size 4850, which is longer than the specified 0
# Created a chunk of size 3724, which is longer than the specified 0
# Created a chunk of size 1134, which is longer than the specified 0
# Created a chunk of size 3136, which is longer than the specified 0
# Created a chunk of size 999, which is longer than the specified 0
# Created a chunk of size 235, which is longer than the specified 0
# Created a chunk of size 995, which is longer than the specified 0
# Created a chunk of size 18140, which is longer than the specified 0
# Created a chunk of size 249, which is longer than the specified 0
# Created a chunk of size 568, which is longer than the specified 0
# Created a chunk of size 304, which is longer than the specified 0
# Created a chunk of size 499, which is longer than the specified 0
# Created a chunk of size 280, which is longer than the specified 0
# Created a chunk of size 233, which is longer than the specified 0
# Created a chunk of size 755, which is longer than the specified 0
# Created a chunk of size 272, which is longer than the specified 0
# Created a chunk of size 639, which is longer than the specified 0
# Created a chunk of size 218, which is longer than the specified 0
# Created a chunk of size 233, which is longer than the specified 0
# Created a chunk of size 249, which is longer than the specified 0
# Created a chunk of size 367, which is longer than the specified 0
# Created a chunk of size 6963, which is longer than the specified 0
# Created a chunk of size 293, which is longer than the specified 0
# Created a chunk of size 357, which is longer than the specified 0
# Created a chunk of size 198, which is longer than the specified 0
# Created a chunk of size 217, which is longer than the specified 0
# Created a chunk of size 6725, which is longer than the specified 0
# Created a chunk of size 573, which is longer than the specified 0
# Created a chunk of size 311, which is longer than the specified 0
# Created a chunk of size 533, which is longer than the specified 0
# Created a chunk of size 560, which is longer than the specified 0
# Created a chunk of size 2833, which is longer than the specified 0
# Created a chunk of size 671, which is longer than the specified 0
# Created a chunk of size 225, which is longer than the specified 0
# Created a chunk of size 429, which is longer than the specified 0
# Created a chunk of size 232, which is longer than the specified 0
# Created a chunk of size 207, which is longer than the specified 0
# Created a chunk of size 329, which is longer than the specified 0
# Created a chunk of size 510, which is longer than the specified 0
# Created a chunk of size 2055, which is longer than the specified 0
# Created a chunk of size 322, which is longer than the specified 0
# Created a chunk of size 1303, which is longer than the specified 0
# Created a chunk of size 650, which is longer than the specified 0
# Created a chunk of size 1083, which is longer than the specified 0
# Created a chunk of size 462, which is longer than the specified 0
# Created a chunk of size 861, which is longer than the specified 0
# Created a chunk of size 835, which is longer than the specified 0
# Created a chunk of size 392, which is longer than the specified 0
# Created a chunk of size 525, which is longer than the specified 0
# Created a chunk of size 417, which is longer than the specified 0
# Created a chunk of size 566, which is longer than the specified 0
# Created a chunk of size 453, which is longer than the specified 0
# Created a chunk of size 332, which is longer than the specified 0
# Created a chunk of size 255, which is longer than the specified 0
# Created a chunk of size 1392, which is longer than the specified 0
# Created a chunk of size 654, which is longer than the specified 0
# Created a chunk of size 627, which is longer than the specified 0
# Created a chunk of size 659, which is longer than the specified 0
# Created a chunk of size 317, which is longer than the specified 0
# Created a chunk of size 391, which is longer than the specified 0
# Created a chunk of size 534, which is longer than the specified 0
# Created a chunk of size 984, which is longer than the specified 0
# Created a chunk of size 267, which is longer than the specified 0
# Created a chunk of size 373, which is longer than the specified 0
# Created a chunk of size 569, which is longer than the specified 0
# Created a chunk of size 628, which is longer than the specified 0
# Created a chunk of size 674, which is longer than the specified 0
# Created a chunk of size 541, which is longer than the specified 0
# Created a chunk of size 237, which is longer than the specified 0
# Created a chunk of size 3744, which is longer than the specified 0
# Created a chunk of size 483, which is longer than the specified 0
# Created a chunk of size 538, which is longer than the specified 0
# Created a chunk of size 705, which is longer than the specified 0
# Created a chunk of size 466, which is longer than the specified 0
# Created a chunk of size 573, which is longer than the specified 0
# Created a chunk of size 651, which is longer than the specified 0
# Created a chunk of size 1242, which is longer than the specified 0
# Created a chunk of size 378, which is longer than the specified 0
# Created a chunk of size 321, which is longer than the specified 0
# Created a chunk of size 683, which is longer than the specified 0
# Created a chunk of size 621, which is longer than the specified 0
# Created a chunk of size 450, which is longer than the specified 0
# Created a chunk of size 536, which is longer than the specified 0
# Created a chunk of size 558, which is longer than the specified 0
# Created a chunk of size 570, which is longer than the specified 0
# Created a chunk of size 839, which is longer than the specified 0
# Created a chunk of size 208, which is longer than the specified 0
# Created a chunk of size 352, which is longer than the specified 0
# Created a chunk of size 715, which is longer than the specified 0
# Created a chunk of size 545, which is longer than the specified 0
# Created a chunk of size 856, which is longer than the specified 0
# Created a chunk of size 786, which is longer than the specified 0
# Created a chunk of size 839, which is longer than the specified 0
# Created a chunk of size 708, which is longer than the specified 0
# Created a chunk of size 713, which is longer than the specified 0
# Created a chunk of size 741, which is longer than the specified 0
# Created a chunk of size 737, which is longer than the specified 0
# Created a chunk of size 4870, which is longer than the specified 0
# Created a chunk of size 5609, which is longer than the specified 0
# Created a chunk of size 934, which is longer than the specified 0
# Created a chunk of size 4062, which is longer than the specified 0
# Created a chunk of size 2112, which is longer than the specified 0
# Created a chunk of size 3503, which is longer than the specified 0
# Created a chunk of size 398, which is longer than the specified 0
# Created a chunk of size 1133, which is longer than the specified 0
# Created a chunk of size 294, which is longer than the specified 0

# %%
# Load a free embedding model (MiniLM is lightweight & fast)
embedding_function = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# Create ChromaDB with local embeddings
db_movies = Chroma.from_documents(documents, embedding=embedding_function)
# Out:
# C:\Users\batuh\AppData\Local\Temp\ipykernel_12356\3959727471.py:2: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding_function = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# %%
query = "A movie to spy on the enemy"
docs = db_movies.similarity_search(query, k = 10)
docs
# Out:
# [Document(id='ab7a9aff-f792-4f1b-83e0-d80aaad68301', metadata={'source': 'tagged_plots.txt'}, page_content='"\n"4335336 The plot involves rogue elements of the communist Chinese army who use fantastic burrowing machines in an effort to place atomic bombs under major U.S. cities. The U.S. Navy sends troops underground to combat them. The film has been described as ""deliriously paranoid"".'),
#  Document(id='8f117073-fad0-4b16-9d0c-413655bb23d8', metadata={'source': 'tagged_plots.txt'}, page_content='"\n1437226 The plot involves a U.S. effort to root out Nazi saboteurs at a shipyard during World War II. Pat O\'Brien plays an American intelligence officer who goes undercover at the yard, working at a construction job and looking for possible spies among the managers and employees.'),
#  Document(id='4c4d4244-28dd-46bf-b3b2-fa4a7c4f6c1b', metadata={'source': 'tagged_plots.txt'}, page_content='"\n6645863 The film tells the tale of two policemen who go undercover to defeat narcotics trafficking among high school gangs. The film featured stark scenes of violence between inter-racial gangs, seemingly in order to portray an anti-discrimination sentiment.'),
#  Document(id='102d2391-9d0b-4444-930c-049f8d8944e0', metadata={'source': 'tagged_plots.txt'}, page_content='"\n"3977641 The movie is set in the year 1941, months before the German invasion of Russia. The two protagonists, NKVD officers Dorin and Oktyabrsky, are hunting a German spy in Moscow. They believe their success might reveal Hitler\'s plans and the exact date of invasion.\n It is implied that Dorin is a distant relative of Erast Fandorin, the most popular character of Akunin\'s books.'),
#  Document(id='79cdaa7c-7ec6-4fa6-8145-99d191c0cca3', metadata={'source': 'tagged_plots.txt'}, page_content="2877046 This film is about a small unit of 40 Turkish soldiers in a remote patrol station in eastern Turkey, in a state of near certain death, during the most violent times, in the conflict between the Turkish Army and the Kurdistan Workers' Party (PKK)."),
#  Document(id='d737a508-92fd-4b03-b851-37deb347a2d1', metadata={'source': 'tagged_plots.txt'}, page_content='"\n1768560 Charlie is a soldier who suffers the scorn of his paratroop unit because he accidentally kills one of their own men. The film is set in World War II in North Africa, Sicily, and Italy.'),
#  Document(id='5fc23c66-9c6a-4129-aa9d-1cafcf2b15a9', metadata={'source': 'tagged_plots.txt'}, page_content='6019668 The story is of terrorism that’s plaguing different parts of the Northeast as the backdrop. Silajit Majumder, a militant on the run, takes refuge in a dilapidated mansion. Roopa Ganguly stays there with her father-in-law Soumitra Chatterjee and his father Haradhan Bandopadhyay who’s confined to bed and is unable to speak. This film focuses on the friction and undercurrent of tension between the lady of the house and the terrorist. It leads to a brief mutual self-discovery that gives rise to compassion.'),
#  Document(id='1fb3200b-ca1d-4c0c-960d-c64554cf4853', metadata={'source': 'tagged_plots.txt'}, page_content='"\n9765123 The movie is based on the Sand mafia and highlights the sacrifice of honest Government officers, who prevent the uncontrollable theft of sand, which no government has been able to stop.'),
#  Document(id='1b37a7c3-dea2-41a5-9e4e-6b4968254d04', metadata={'source': 'tagged_plots.txt'}, page_content='"\n5509552 The film brims with British comedy talent of the period. The Crazy Gang’s mobile fish and chip shop is accidentally tied to a barrage balloon and the gang is carried to Nazi Germany. They are captured but break out of prison, impersonate Adolf Hitler and return to England in a stolen secret weapon.'),
#  Document(id='783682d6-574b-4477-82ee-e517de70b4c0', metadata={'source': 'tagged_plots.txt'}, page_content="8306134 The film takes place in Antarctica, centering around a rescue team that was sent to the Routledge research station to investigate a research team's lack of communication with the outside world. Once there, the team discovers no survivors in the research station but finds a diary that describes the research team's last days. The diary goes over the research team's growing malcontent and paranoia as the team is picked off one by one by a mysterious killer.")]

# %%
def retrieve_semantic_recommendations(
        query: str,
        top_k: int = 10,
) -> pd.DataFrame:
    recs = db_movies.similarity_search(query, k = 50)

    movies_list = []

    for i in range(0, len(recs)):
        movies_list += [int(recs[i].page_content.strip('"').strip("\n").strip('"').split()[0])]

    return movies[movies["unique_id"].isin(movies_list)]

# %%
retrieve_semantic_recommendations("A movie to spy on the enemy")
# Out:
#        Release Year                                              Title  \
# 64             1914                                    Captain Alvarez
# 571            1926                                          Hands Up!
# 3237           1942                                        Spy Smasher
# 3692           1944                                     Secret Command
# 5069           1951                               Decision Before Dawn
# 6833           1958                         Wind Across the Everglades
# 6935           1959                                  Paratroop Command
# 7056           1960                                         Pay or Die
# 7087           1960                                   This Rebel Breed
# 7301           1962                                         Moon Pilot
# 8140           1969                                             Shark!
# 8598           1973                                     Oklahoma Crude
# 9863           1984                            The Little Drummer Girl
# 10155          1986                                       Getting Even
# 10646          1988                                         Off Limits
# 10954          1990                 American Ninja 4: The Annihilation
# 11209          1991                                   Company Business
# 12504          1997                                     The Assignment
# 12728          1997                                  Strategic Command
# 14436          2006                                         Civic Duty
# 14550          2006                                  Land of the Blind
# 16842          2017                                     Armed Response
# 17901          1941                                            Gasbags
# 18283          1951                              Where No Vultures Fly
# 18363          1953                                  It's a Grand Life
# 19081          1967                           Battle Beneath the Earth
# 20466          2012                                    South of Sanity
# 21783          2012                                     Guns and Roses
# 21898          2015                                       Agent F.O.X.
# 23058          2005                                         Krantikaal
# 24495          1988                                           Commando
# 24792          1995                                   Policewala Gunda
# 24918          1998                             Bade Miyan Chote Miyan
# 26323          2009                                 Venkata in Sankata
# 26384          2012                                           Chingari
# 27677          2016                                               Reti
# 27825          1945                                         Burma Rani
# 28395          1977                                    Aadu Puli Attam
# 29175          1999                                              Sivan
# 30692          1989                                Adavilo Abhimanyudu
# 31377          2013                                              Dalam
# 32064          1999                      Nobita Drifts in the Universe
# 32395          2011  Crayon Shin-chan: The Storm Called: Operation ...
# 32825          2002                                           The Star
# 32844          2005                                   Dead Man's Bluff
# 32889          2008                                            Admiral
# 32942          2012                                                Spy
# 32949          2012                                         In the Fog
# 33521          2009                              Nefes: Vatan Sağolsun
# 33549          2010                          Five Minarets in New York
#
#       Origin/Ethnicity                     Director  \
# 64            American           Rollin S. Sturgeon
# 571           American              Clarence Badger
# 3237          American               William Witney
# 3692          American         A. Edward Sutherland
# 5069          American               Anatole Litvak
# 6833          American                 Nicholas Ray
# 6935          American               William Witney
# 7056          American               Richard Wilson
# 7087          American              Richard L. Bare
# 7301          American                James Neilson
# 8140          American                Samuel Fuller
# 8598          American               Stanley Kramer
# 9863          American              George Roy Hill
# 10155         American             Dwight H. Little
# 10646         American            Christopher Crowe
# 10954         American             Cedric Sundstrom
# 11209         American               Nicholas Meyer
# 12504         American             Christian Duguay
# 12728         American                      Unknown
# 14436         American                 Jeff Renfroe
# 14550         American               Robert Edwards
# 16842         American               John Stockwell
# 17901          British  Walter Forde, Marcel Varnel
# 18283          British                   Harry Watt
# 18363          British             John E. Blakeley
# 19081          British             Montgomery Tully
# 20466          British    Directors: Mathew Edwards
# 21783          Chinese                     Ning Hao
# 21898          Chinese                  Ge Shuiying
# 23058          Bengali                   Sekhar Das
# 24495        Bollywood                   B. Subhash
# 24792        Bollywood                  Pappu Verma
# 24918        Bollywood                 David Dhawan
# 26323          Kannada                Ramesh Arvind
# 26384          Kannada                       Harsha
# 27677          Marathi                Suhas Bhosale
# 27825            Tamil               T. R. Sundaram
# 28395            Tamil             S. P. Muthuraman
# 29175            Tamil             Velu Prabhakaran
# 30692           Telugu                         Anil
# 31377           Telugu                 Jeevan Reddy
# 32064         Japanese            Tsutomu Shibayama
# 32395         Japanese                 Sōichi Masui
# 32825          Russian              Nikolai Lebedev
# 32844          Russian            Aleksei Balabanov
# 32889          Russian              Andrei Kravchuk
# 32942          Russian            Aleksey Andrianov
# 32949          Russian              Sergei Loznitsa
# 33521          Turkish               Levent Semerci
# 33549          Turkish            Mahsun Kırmızıgül
#
#                                  Genre  \
# 64                    historical drama
# 571                             comedy
# 3237                        spy serial
# 3692                             drama
# 5069                               war
# 6833                             drama
# 6935                         war drama
# 7056                             crime
# 7087                       crime drama
# 7301                            comedy
# 8140                            action
# 8598                             drama
# 9863                          thriller
# 10155                            drama
# 10646                       drama, war
# 10954                           action
# 11209                              spy
# 12504                            drama
# 12728                          unknown
# 14436                            drama
# 14550                            drama
# 16842         thriller, sci-fi, action
# 17901                           comedy
# 18283                african adventure
# 18363                           comedy
# 19081                           sci-fi
# 20466                          unknown
# 21783          comedy / action / drama
# 21898  animation / fantasy / adventure
# 23058                          romance
# 24495           action, drama, romance
# 24792                          unknown
# 24918                           comedy
# 26323                           comedy
# 26384                   romance-action
# 27677                 action, thriller
# 27825                          unknown
# 28395                          unknown
# 29175                          unknown
# 30692                          unknown
# 31377                           action
# 32064                          unknown
# 32395                            anime
# 32825                              war
# 32844                    crime, comedy
# 32889                 historical drama
# 32942                          unknown
# 32949                          unknown
# 33521                            drama
# 33549                           action
#
#                                                Wiki Page  \
# 64         https://en.wikipedia.org/wiki/Captain_Alvarez
# 571    https://en.wikipedia.org/wiki/Hands_Up!_(1926_...
# 3237   https://en.wikipedia.org/wiki/Spy_Smasher_(ser...
# 3692        https://en.wikipedia.org/wiki/Secret_Command
# 5069   https://en.wikipedia.org/wiki/Decision_Before_...
# 6833   https://en.wikipedia.org/wiki/Wind_Across_the_...
# 6935     https://en.wikipedia.org/wiki/Paratroop_Command
# 7056            https://en.wikipedia.org/wiki/Pay_or_Die
# 7087      https://en.wikipedia.org/wiki/This_Rebel_Breed
# 7301            https://en.wikipedia.org/wiki/Moon_Pilot
# 8140         https://en.wikipedia.org/wiki/Shark!_(film)
# 8598   https://en.wikipedia.org/wiki/Oklahoma_Crude_(...
# 9863   https://en.wikipedia.org/wiki/The_Little_Drumm...
# 10155  https://en.wikipedia.org/wiki/Getting_Even_(19...
# 10646  https://en.wikipedia.org/wiki/Off_Limits_(1988...
# 10954  https://en.wikipedia.org/wiki/American_Ninja_4...
# 11209     https://en.wikipedia.org/wiki/Company_Business
# 12504  https://en.wikipedia.org/wiki/The_Assignment_(...
# 12728  https://en.wikipedia.org/wiki/Strategic_Comman...
# 14436    https://en.wikipedia.org/wiki/Civic_Duty_(film)
# 14550    https://en.wikipedia.org/wiki/Land_of_the_Blind
# 16842  https://en.wikipedia.org/wiki/Armed_Response_(...
# 17901              https://en.wikipedia.org/wiki/Gasbags
# 18283  https://en.wikipedia.org/wiki/Where_No_Vulture...
# 18363  https://en.wikipedia.org/wiki/It%27s_a_Grand_Life
# 19081  https://en.wikipedia.org/wiki/Battle_Beneath_t...
# 20466      https://en.wikipedia.org/wiki/South_of_Sanity
# 21783  https://en.wikipedia.org/wiki/Guns_and_Roses_(...
# 21898         https://en.wikipedia.org/wiki/Agent_F.O.X.
# 23058           https://en.wikipedia.org/wiki/Krantikaal
# 24495  https://en.wikipedia.org/wiki/Commando_(1988_f...
# 24792     https://en.wikipedia.org/wiki/Policewala_Gunda
# 24918  https://en.wikipedia.org/wiki/Bade_Miyan_Chote...
# 26323   https://en.wikipedia.org/wiki/Venkata_in_Sankata
# 26384  https://en.wikipedia.org/wiki/Chingari_(2012_f...
# 27677          https://en.wikipedia.org/wiki/Reti_(film)
# 27825           https://en.wikipedia.org/wiki/Burma_Rani
# 28395  https://en.wikipedia.org/wiki/Aadu_Puli_Attam_...
# 29175         https://en.wikipedia.org/wiki/Sivan_(film)
# 30692  https://en.wikipedia.org/wiki/Adavilo_Abhimanyudu
# 31377         https://en.wikipedia.org/wiki/Dalam_(film)
# 32064  https://en.wikipedia.org/wiki/Doraemon:_Nobita...
# 32395  https://en.wikipedia.org/wiki/Crayon_Shin-chan...
# 32825  https://en.wikipedia.org/wiki/The_Star_(2002_f...
# 32844   https://en.wikipedia.org/wiki/Dead_Man%27s_Bluff
# 32889  https://en.wikipedia.org/wiki/The_Admiral_(200...
# 32942  https://en.wikipedia.org/wiki/Spy_(2012_Russia...
# 32949           https://en.wikipedia.org/wiki/In_the_Fog
# 33521  https://en.wikipedia.org/wiki/Nefes:_Vatan_Sa%...
# 33549  https://en.wikipedia.org/wiki/Five_Minarets_in...
#
#                                                     Plot  words_in_plot  \
# 64     A melodrama about an American who becomes a re...             41
# 571    The film tells the story of Jack, a spy for th...             62
# 3237   Alan Armstrong (Kane Richmond) as the Spy Smas...            197
# 3692   The plot involves a U.S. effort to root out Na...             46
# 5069   By late 1944, it is obvious that the Germans w...            507
# 6833   Set in the early 20th century, the film follow...             73
# 6935   Charlie is a soldier who suffers the scorn of ...             35
# 7056   The film is a dramatization of the career of c...             51
# 7087   The film tells the tale of two policemen who g...             37
# 7301   Air Force Capt. Richmond Talbot inadvertently ...            226
# 8140   Reynolds plays Caine, a gunrunner who becomes ...             60
# 8598   Set in the early 20th century, the film is abo...             70
# 9863   Set in Europe and the Middle East, the plot fo...            489
# 10155  A soldier-of-fortune, Tag Taggert, played by E...             59
# 10646  Although set during the war, the tale is more ...            204
# 10954  C.I.A. Agent Sean Davidson (David Bradley) is ...            399
# 11209  The film follows the exploits of Sam Boyd (Gen...            177
# 12504  The film opens to the sounds of a couple havin...            782
# 12728  Rick Harding (Dudikoff) is a former Marines of...             81
# 14436  The film is about an American accountant bomba...             37
# 14550  Hollander plays Maximilian II (often called Ju...            813
# 16842  A team of trained operatives find themselves t...             40
# 17901  The film brims with British comedy talent of t...             53
# 18283  The film is set in East Africa. It is about a ...             51
# 18363  The film is described in its opening titles as...             96
# 19081  The plot involves rogue elements of the commun...             43
# 20466  The film takes place in Antarctica, centering ...             77
# 21783  The film is set in the 1930s in Changchun, cap...            686
# 21898  Super spy Agent F.O.X. arrives in Carrot Town ...             42
# 23058  The story is of terrorism that’s plaguing diff...             82
# 24495  Commando is an action film in the genre of Jam...             64
# 24792  This movie revolves around a policeman (Mukesh...             81
# 24918  This movie is 'inspired' from the 1995 action-...            476
# 26323  The film is all about a traffic constable Venk...             83
# 26384  The movie revolves around a Super cop C.C.B. o...             30
# 27677  The movie is based on the Sand mafia and highl...             31
# 27825  The story revolves around a spy ring in Japane...             95
# 28395  The movie starts with Kamal and Rajini, close ...             86
# 29175  The film starts with a terrorist group enterin...            518
# 30692  The film's story is based on the Indian Army's...             47
# 31377  The Scene begins in a Naxal infested area, whe...             70
# 32064  The film is the second in the series to parody...             57
# 32395  A girl named Lemon suddenly appears. She shows...            228
# 32825  A team of Soviet scouts is sent behind enemy l...            140
# 32844  The film opens with a professor lecturing a gr...           1264
# 32889  The film opens during the production of War an...           1200
# 32942  The movie is set in the year 1941, months befo...             63
# 32949  The film is an adaptation from Vasil’ Bykaw's ...            150
# 33521  This film is about a small unit of 40 Turkish ...             44
# 33549  The film follows two anti-terror officers from...             74
#
#        unique_id                                       tagged_plots
# 64       1869617  1869617 A melodrama about an American who beco...
# 571      1405581  1405581 The film tells the story of Jack, a sp...
# 3237     9113765  9113765 Alan Armstrong (Kane Richmond) as the ...
# 3692     1437226  1437226 The plot involves a U.S. effort to roo...
# 5069     5738014  5738014 By late 1944, it is obvious that the G...
# 6833     8488427  8488427 Set in the early 20th century, the fil...
# 6935     1768560  1768560 Charlie is a soldier who suffers the s...
# 7056     4237026  4237026 The film is a dramatization of the car...
# 7087     6645863  6645863 The film tells the tale of two policem...
# 7301     6627864  6627864 Air Force Capt. Richmond Talbot inadve...
# 8140     4999407  4999407 Reynolds plays Caine, a gunrunner who ...
# 8598     9445480  9445480 Set in the early 20th century, the fil...
# 9863     5212196  5212196 Set in Europe and the Middle East, the...
# 10155    5662290  5662290 A soldier-of-fortune, Tag Taggert, pla...
# 10646    9992723  9992723 Although set during the war, the tale ...
# 10954    4132705  4132705 C.I.A. Agent Sean Davidson (David Brad...
# 11209    7813686  7813686 The film follows the exploits of Sam B...
# 12504    6369116  6369116 The film opens to the sounds of a coup...
# 12728    8986360  8986360 Rick Harding (Dudikoff) is a former Ma...
# 14436    2300881  2300881 The film is about an American accounta...
# 14550    2959097  2959097 Hollander plays Maximilian II (often c...
# 16842    3236234  3236234 A team of trained operatives find them...
# 17901    5509552  5509552 The film brims with British comedy tal...
# 18283    9045812  9045812 The film is set in East Africa. It is ...
# 18363    5102919  5102919 The film is described in its opening t...
# 19081    4335336  4335336 The plot involves rogue elements of th...
# 20466    8306134  8306134 The film takes place in Antarctica, ce...
# 21783    6903933  6903933 The film is set in the 1930s in Changc...
# 21898    3185336  3185336 Super spy Agent F.O.X. arrives in Carr...
# 23058    6019668  6019668 The story is of terrorism that’s plagu...
# 24495    3928102  3928102 Commando is an action film in the genr...
# 24792    5196119  5196119 This movie revolves around a policeman...
# 24918    7220275  7220275 This movie is 'inspired' from the 1995...
# 26323    9187686  9187686 The film is all about a traffic consta...
# 26384    3922579  3922579 The movie revolves around a Super cop ...
# 27677    9765123  9765123 The movie is based on the Sand mafia a...
# 27825    1027156  1027156 The story revolves around a spy ring i...
# 28395    3319873  3319873 The movie starts with Kamal and Rajini...
# 29175    8388844  8388844 The film starts with a terrorist group...
# 30692    8022655  8022655 The film's story is based on the India...
# 31377    9053222  9053222 The Scene begins in a Naxal infested a...
# 32064    2434879  2434879 The film is the second in the series t...
# 32395    7883817  7883817 A girl named Lemon suddenly appears. S...
# 32825    4948868  4948868 A team of Soviet scouts is sent behind...
# 32844    4095477  4095477 The film opens with a professor lectur...
# 32889    8914622  8914622 The film opens during the production o...
# 32942    3977641  3977641 The movie is set in the year 1941, mon...
# 32949    6548934  6548934 The film is an adaptation from Vasil’ ...
# 33521    2877046  2877046 This film is about a small unit of 40 ...
# 33549    6445686  6445686 The film follows two anti-terror offic...

# %%
retrieve_semantic_recommendations("A movie to spy on the enemy")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 retrieve_semantic_recommendations("A movie to spy on the enemy")
#
# Cell In[65], line 10, in retrieve_semantic_recommendations(query, top_k)
#       7 movies_list = []
#       9 for i in range(0, len(recs)):
# ---> 10     movies_list += [int(recs[i].page_content.strip('"').split()[0])]
#      12 return movies[movies["unique_id"].isin(movies_list)]
#
# ValueError: invalid literal for int() with base 10: 'The'

# %%
movies["starts_with_num"] = movies["tagged_plots"].str.match(r'^\d+')


# Check if all rows start with a number
all_start_with_number = movies['starts_with_num'].all()
print("Do all sentences start with a number?", all_start_with_number)
# Out:
# Do all sentences start with a number? True
